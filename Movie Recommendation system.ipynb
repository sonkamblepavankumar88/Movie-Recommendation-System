# %% [markdown]
# ## What is Movie Recommendation System?

# %% [markdown]
# ### Using machine learning to predict or filter user's film preferences based on their prior decisions and actions is known as Movie Recommendation System

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### import and read file

# %%
credits = pd.read_csv('credits.csv')
movies = pd.read_csv('movies.csv')

# %%
credits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
# these codes are to display all the columns in file
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
credits.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
credits.tail(5)
# Out:
#       movie_id                      title  \
# 4798      9367                El Mariachi
# 4799     72766                  Newlyweds
# 4800    231617  Signed, Sealed, Delivered
# 4801    126186           Shanghai Calling
# 4802     25975          My Date with Drew
#
#                                                    cast  \
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 4798  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4800  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4801  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4802  [{"credit_id": "58ce021b9251415a390165d9", "de...

# %%
movies.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.tail(5)
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %% [markdown]
# ### Merge 2 files on a column

# %%
movies = movies.merge(credits, on = 'title')

# %%
movies.shape
# Out:
# (4787, 23)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4787 entries, 0 to 4786
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4787 non-null   int64
#  1   genres                4787 non-null   object
#  2   homepage              1707 non-null   object
#  3   id                    4787 non-null   int64
#  4   keywords              4787 non-null   object
#  5   original_language     4787 non-null   object
#  6   original_title        4787 non-null   object
#  7   overview              4783 non-null   object
#  8   popularity            4787 non-null   float64
#  9   production_companies  4787 non-null   object
#  10  production_countries  4787 non-null   object
#  11  release_date          4786 non-null   object
#  12  revenue               4787 non-null   int64
#  13  runtime               4785 non-null   float64
#  14  spoken_languages      4787 non-null   object
# ...

# %%
movies.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.787000e+03    4787.000000  4787.000000  4.787000e+03  4785.000000
# mean   2.904013e+07   57078.888239    21.483743  8.229040e+07   106.918495
# std    4.071263e+07   88605.304353    31.846703  1.629477e+08    22.612392
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.785000e+05    9010.500000     4.666270  0.000000e+00    94.000000
# 50%    1.500000e+07   14624.000000    12.893219  1.917000e+07   104.000000
# 75%    4.000000e+07   58584.500000    28.252232  9.295652e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count       movie_id
# count   4787.000000   4787.000000    4787.000000
# mean       6.092459    689.494255   57078.888239
# std        1.190776   1233.274611   88605.304353
# min        0.000000      0.000000       5.000000
# ...

# %% [markdown]
# ### display columns only you want

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4787 entries, 0 to 4786
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4787 non-null   int64
#  1   title     4787 non-null   object
#  2   overview  4783 non-null   object
#  3   genres    4787 non-null   object
#  4   keywords  4787 non-null   object
#  5   cast      4787 non-null   object
#  6   crew      4786 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 299.2+ KB

# %% [markdown]
# ### Check null values

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    4
# genres      0
# keywords    0
# cast        0
# crew        1
# dtype: int64

# %% [markdown]
# ### drop all null values

# %%
movies.dropna(inplace=True)

# %% [markdown]
# ### check duplicate values

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %% [markdown]
# ### import Abstract Syntax Tree

# %%
import ast

# %% [markdown]
# #### An Abstract Syntax Tree, or AST, is a tree representation of the source code of a computer program that conveys the structure of the source code. Each node in the tree represents a construct occurring in the source code.

# %% [markdown]
# ### import warnings to ignore all the warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def convert(obj):
    l = []
    for i in ast.literal_eval(obj):
        l.append(i['name'])
    return l

# %% [markdown]
# ### Converting stringified lists in 'genres', 'keywords', 'cast', and 'crew' columns into actual lists using the ast.literal_eval() function.

# %%
movies['genres'] = movies['genres'].apply(convert)
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
def convert3(obj):
    L=[]
    counter = 0
    for i in ast.literal_eval(obj):
        if counter != 3:
            L.append(i['name'])
            counter += 1
        else:
            break
        return L

# %% [markdown]
# ### This function is specifically designed to extract a maximum of 3 'name' values from a list of dictionaries.

# %%
movies['cast'] = movies['cast'].apply(convert3)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
def fetch_director(obj):
    l = []
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            l.append(i['name'])
    return l

# %% [markdown]
# ### This function is typically used to extract the names of directors from a column that contains a stringified list of dictionaries, where each dictionary represents a person's job and name associated with a particular movie.

# %%
movies['crew']=movies['crew'].apply(fetch_director)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['overview'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
movies['overview']=movies['overview'].apply(lambda x:x.split())

# %% [markdown]
# ###  this code splits the 'overview' column of the 'movies' dataframe, treating each string value as a sentence or collection of words, and converts it into a list of individual words. This can be useful for further processing or analysis that requires working with individual words rather than entire sentences.

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['genres'] = movies['genres'].apply(lambda x: [i.replace("", "") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x: [i.replace("", "") for i in x])
movies['cast'] = movies['cast'].apply(lambda x: [i.replace("", "") for i in x] if x is not None else [])
movies['crew'] = movies['crew'].apply(lambda x: [i.replace("", "") for i in x] if x is not None else [])

# %% [markdown]
# ### these lines of code remove any occurrence of empty strings ("") within the lists present in the 'genres', 'keywords', 'cast', and 'crew' columns of the 'movies' dataframe.

# %%
movies['tags'] = movies['overview']+movies['genres']+movies['keywords']+movies['cast']+movies['crew']

# %% [markdown]
# ### this code combines the information from different columns into a single column named 'tags', which can be used as a consolidated representation of various aspects of a movie, including its overview, genres, keywords, cast, and crew.

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
new = movies[['movie_id', 'title', 'tags']]

# %%
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
new['tags'] = new['tags'].apply(lambda x: ' '.join(x))

# %% [markdown]
# ### this code converts the 'tags' column from a list of words into a single string by joining the individual words with a space between them

# %%
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
new['tags'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. Action Adventure Fantasy Science Fiction culture clash future space war space colony society space travel futuristic romance space alien tribe alien planet cgi marine soldier battle love affair anti war power relations mind and soul 3d Sam Worthington James Cameron'

# %%
new['tags']=new['tags'].apply(lambda X:X.lower())

# %%
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 5000,stop_words = 'english')

# %% [markdown]
# ### this code sets up a CountVectorizer object with specific configuration options, such as the maximum number of features and the use of English stop words, to facilitate the extraction of features from text data.

# %%
cv.fit_transform(new['tags']).toarray().shape
# Out:
# (4782, 5000)

# %%
vectors = cv.fit_transform(new['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
len(cv.get_feature_names())
# Out:
# 5000

# %%
import nltk

# %% [markdown]
# ### Natural Language Toolkit, is a Python package that you can use for NLP. A lot of the data that you could be analyzing is unstructured data and contains human-readable text. Before you can analyze that data programmatically, you first need to preprocess it.

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %% [markdown]
# ### this code sets up the PorterStemmer object 'ps', which can be used to perform stemming operations on words in text data.

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %% [markdown]
# ### this code defines a function that applies stemming to the words in a given text. The function uses the PorterStemmer object 'ps' to perform the stemming operation and returns the stemmed text as output.

# %%
new['tags'] = new['tags'].apply(stem)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### the cosine_similarity function is used to calculate the cosine similarity between vectors or matrices, providing a measure of similarity between them.

# %%
cosine_similarity(vectors)
# Out:
# array([[1.        , 0.07362102, 0.05157106, ..., 0.03300492, 0.0559017 ,
#         0.        ],
#        [0.07362102, 1.        , 0.04556057, ..., 0.0437374 , 0.        ,
#         0.        ],
#        [0.05157106, 0.04556057, 1.        , ..., 0.02042518, 0.09225312,
#         0.        ],
#        ...,
#        [0.03300492, 0.0437374 , 0.02042518, ..., 1.        , 0.06642112,
#         0.03528374],
#        [0.0559017 , 0.        , 0.09225312, ..., 0.06642112, 1.        ,
#         0.03984095],
#        [0.        , 0.        , 0.        , ..., 0.03528374, 0.03984095,
#         1.        ]])

# %%
cosine_similarity(vectors).shape
# Out:
# (4782, 4782)

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[0]
# Out:
# array([1.        , 0.07362102, 0.05157106, ..., 0.03300492, 0.0559017 ,
#        0.        ])

# %%
similarity[0].shape
# Out:
# (4782,)

# %%
sorted(list(enumerate(similarity[0])),reverse = True, key = lambda x:x[1])[1:6]
# Out:
# [(2397, 0.46423834544262965),
#  (1528, 0.4479893351905204),
#  (371, 0.4151682458530185),
#  (4315, 0.40929374234328036),
#  (3148, 0.4056043231767331)]

# %% [markdown]
# ###  the code sorts the similarity values of the first row in descending order and selects the top 5 elements (excluding the first element). These elements correspond to the indices of the most similar movies to the first movie in the similarity matrix.

# %%
def recommend(movie):
    movie_index = new[new['title']==movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances )),reverse = True, key = lambda x:x[1])[1:6]
    
    for i in movies_list:
        print(new.iloc[i[0]].title)

# %% [markdown]
# ### the 'recommend' function retrieves the index of a given movie, calculates the similarity values between that movie and all other movies, selects the top 5 similar movies, and prints their titles as recommendations.

# %% [markdown]
# ### Check the codes are working correctly

# %%
recommend('Avatar')
# Out:
# Aliens
# Moonraker
# Mission to Mars
# Silent Running
# Alien

# %%
recommend('Iron Man')
# Out:
# Extremely Loud & Incredibly Close
# The Young and Prodigious T.S. Spivet
# Little Boy
# Dear Frankie
# When Did You Last See Your Father?

# %%
recommend('Liar Liar')
# Out:
# Maria Full of Grace
# Trainspotting
# The French Connection
# The Counselor
# Traffic

# %%
recommend('The Avengers')
# Out:
# Avengers: Age of Ultron
# Iron Man 2
# Fantastic Four
# Iron Man
# X-Men

# %% [markdown]
# # "Project successfully completed."
